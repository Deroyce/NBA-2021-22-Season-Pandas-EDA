# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\dlewis2\Desktop\Sample data files 08.15.21\StackOverflowSurveyData2021.csv')

# %% [markdown]
# ### Explore the data

# %%
df.head()
# Out:
#    ResponseId                                         MainBranch  \
# 0           1                     I am a developer by profession
# 1           2             I am a student who is learning to code
# 2           3  I am not primarily a developer, but I write co...
# 3           4                     I am a developer by profession
# 4           5                     I am a developer by profession
#
#                                           Employment  \
# 0  Independent contractor, freelancer, or self-em...
# 1                                 Student, full-time
# 2                                 Student, full-time
# 3                                 Employed full-time
# 4  Independent contractor, freelancer, or self-em...
#
#                                              Country US_State UK_Country  \
# 0                                           Slovakia      NaN        NaN
# 1                                        Netherlands      NaN        NaN
# ...

# %%
df.tail()
# Out:
#        ResponseId                      MainBranch  \
# 83434       83435  I am a developer by profession
# 83435       83436  I am a developer by profession
# 83436       83437  I am a developer by profession
# 83437       83438  I am a developer by profession
# 83438       83439  I am a developer by profession
#
#                                               Employment  \
# 83434                                 Employed full-time
# 83435  Independent contractor, freelancer, or self-em...
# 83436                                 Employed full-time
# 83437                                 Employed full-time
# 83438                                 Employed full-time
#
#                         Country    US_State UK_Country  \
# 83434  United States of America       Texas        NaN
# 83435                     Benin         NaN        NaN
# 83436  United States of America  New Jersey        NaN
# 83437                    Canada         NaN        NaN
# ...

# %%
df.shape
# Out:
# (83439, 48)

# %%
df.describe()
# Out:
#          ResponseId     CompTotal  ConvertedCompYearly
# count  83439.000000  4.718300e+04         4.684400e+04
# mean   41720.000000  2.119407e+69         1.184262e+05
# std    24086.908893  4.603702e+71         5.272944e+05
# min        1.000000  0.000000e+00         1.000000e+00
# 25%    20860.500000  1.600000e+04         2.702500e+04
# 50%    41720.000000  6.700000e+04         5.621100e+04
# 75%    62579.500000  1.400000e+05         1.000000e+05
# max    83439.000000  1.000000e+74         4.524131e+07

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 83439 entries, 0 to 83438
# Data columns (total 48 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   ResponseId                    83439 non-null  int64
#  1   MainBranch                    83439 non-null  object
#  2   Employment                    83323 non-null  object
#  3   Country                       83439 non-null  object
#  4   US_State                      14920 non-null  object
#  5   UK_Country                    4418 non-null   object
#  6   EdLevel                       83126 non-null  object
#  7   Age1stCode                    83243 non-null  object
#  8   LearnCode                     82963 non-null  object
#  9   YearsCode                     81641 non-null  object
#  10  YearsCodePro                  61216 non-null  object
#  11  DevType                       66484 non-null  object
# ...

# %%
df.dtypes
# Out:
# ResponseId                        int64
# MainBranch                       object
# Employment                       object
# Country                          object
# US_State                         object
# UK_Country                       object
# EdLevel                          object
# Age1stCode                       object
# LearnCode                        object
# YearsCode                        object
# YearsCodePro                     object
# DevType                          object
# OrgSize                          object
# Currency                         object
# CompTotal                       float64
# CompFreq                         object
# LanguageHaveWorkedWith           object
# LanguageWantToWorkWith           object
# DatabaseHaveWorkedWith           object
# DatabaseWantToWorkWith           object
# PlatformHaveWorkedWith           object
# PlatformWantToWorkWith           object
# WebframeHaveWorkedWith           object
# ...

# %%
df.columns
# Out:
# Index(['ResponseId', 'MainBranch', 'Employment', 'Country', 'US_State',
#        'UK_Country', 'EdLevel', 'Age1stCode', 'LearnCode', 'YearsCode',
#        'YearsCodePro', 'DevType', 'OrgSize', 'Currency', 'CompTotal',
#        'CompFreq', 'LanguageHaveWorkedWith', 'LanguageWantToWorkWith',
#        'DatabaseHaveWorkedWith', 'DatabaseWantToWorkWith',
#        'PlatformHaveWorkedWith', 'PlatformWantToWorkWith',
#        'WebframeHaveWorkedWith', 'WebframeWantToWorkWith',
#        'MiscTechHaveWorkedWith', 'MiscTechWantToWorkWith',
#        'ToolsTechHaveWorkedWith', 'ToolsTechWantToWorkWith',
#        'NEWCollabToolsHaveWorkedWith', 'NEWCollabToolsWantToWorkWith', 'OpSys',
#        'NEWStuck', 'NEWSOSites', 'SOVisitFreq', 'SOAccount', 'SOPartFreq',
#        'SOComm', 'NEWOtherComms', 'Age', 'Gender', 'Trans', 'Sexuality',
#        'Ethnicity', 'Accessibility', 'MentalHealth', 'SurveyLength',
#        'SurveyEase', 'ConvertedCompYearly'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# ResponseId                          0
# MainBranch                          0
# Employment                        116
# Country                             0
# US_State                        68519
# UK_Country                      79021
# EdLevel                           313
# Age1stCode                        196
# LearnCode                         476
# YearsCode                        1798
# YearsCodePro                    22223
# DevType                         16955
# OrgSize                         22713
# Currency                        22359
# CompTotal                       36256
# CompFreq                        31289
# LanguageHaveWorkedWith           1082
# LanguageWantToWorkWith           6618
# DatabaseHaveWorkedWith          13893
# DatabaseWantToWorkWith          25140
# PlatformHaveWorkedWith          31304
# PlatformWantToWorkWith          41820
# WebframeHaveWorkedWith          21732
# WebframeWantToWorkWith          31344
# MiscTechHaveWorkedWith          36384
# ...

# %%
#shows each number of column,column, # of rows per column, list of unique values in column
#the'\n' is to add a space between each column info.  **NOT GOING TO SHOW IN PROJECT SINCE IT'S A MASSIVE AMOUNT OF ROWS**

#i=1
#for col in df.columns:  #shows each column, # of rows per column, list of unique values in column
    #print(i,col,'----',len(df[col].unique()),df[col].unique(),'\n')
    #i=i+1

# %% [markdown]
# ### Filter for all coders in US

# %%
USCoders = df.loc[df['Country']=='United States of America']
USCoders.head()
# Out:
#     ResponseId                              MainBranch           Employment  \
# 5            6  I am a student who is learning to code   Student, part-time
# 6            7             I code primarily as a hobby  I prefer not to say
# 15          16  I am a student who is learning to code   Student, full-time
# 36          37          I am a developer by profession   Employed full-time
# 37          38          I am a developer by profession   Employed full-time
#
#                      Country              US_State UK_Country  \
# 5   United States of America               Georgia        NaN
# 6   United States of America         New Hampshire        NaN
# 15  United States of America              Missouri        NaN
# 36  United States of America  District of Columbia        NaN
# 37  United States of America         Massachusetts        NaN
#
#                                               EdLevel     Age1stCode  \
# ...

# %%
USCoders.isnull().sum() #shows number of NA's per field
# Out:
# ResponseId                          0
# MainBranch                          0
# Employment                         22
# Country                             0
# US_State                          368
# UK_Country                      15288
# EdLevel                            73
# Age1stCode                         38
# LearnCode                          73
# YearsCode                         229
# YearsCodePro                     3223
# DevType                          2540
# OrgSize                          3445
# Currency                         3382
# CompTotal                        5347
# CompFreq                         5035
# LanguageHaveWorkedWith            155
# LanguageWantToWorkWith           1204
# DatabaseHaveWorkedWith           3109
# DatabaseWantToWorkWith           5343
# PlatformHaveWorkedWith           4918
# PlatformWantToWorkWith           7072
# WebframeHaveWorkedWith           4393
# WebframeWantToWorkWith           6348
# MiscTechHaveWorkedWith           6896
# ...

# %% [markdown]
# ### Filter for black coders in US

# %%
#this dataframe only includes black americans that are only black
BlackDF = df.loc[(df['Country']=='United States of America')&(df['Ethnicity']=='Black or of African descent')]

# %%
BlackDF.shape
# Out:
# (275, 48)

# %%
BlackDF['Ethnicity'].value_counts()
# Out:
# Black or of African descent    275
# Name: Ethnicity, dtype: int64

# %%
#this dataframe includes Americans that or black or mixed with black
all_black_df = df.loc[(df['Country']=='United States of America')&(df['Ethnicity'].str.contains('Black or of African descent'))]

# %%
all_black_df.shape
# Out:
# (432, 48)

# %%
all_black_df.head()
# Out:
#       ResponseId                                         MainBranch  \
# 1103        1104  I am not primarily a developer, but I write co...
# 1399        1400                        I code primarily as a hobby
# 1662        1663                     I am a developer by profession
# 2547        2548             I am a student who is learning to code
# 2998        2999  I am not primarily a developer, but I write co...
#
#               Employment                   Country  US_State UK_Country  \
# 1103  Employed full-time  United States of America   Florida        NaN
# 1399  Student, full-time  United States of America  Virginia        NaN
# 1662  Employed full-time  United States of America  Michigan        NaN
# 2547  Employed full-time  United States of America   Florida        NaN
# 2998  Employed full-time  United States of America  Illinois        NaN
#
#                                                 EdLevel     Age1stCode  \
# ...

# %%
all_black_df.columns
# Out:
# Index(['ResponseId', 'MainBranch', 'Employment', 'Country', 'US_State',
#        'UK_Country', 'EdLevel', 'Age1stCode', 'LearnCode', 'YearsCode',
#        'YearsCodePro', 'DevType', 'OrgSize', 'Currency', 'CompTotal',
#        'CompFreq', 'LanguageHaveWorkedWith', 'LanguageWantToWorkWith',
#        'DatabaseHaveWorkedWith', 'DatabaseWantToWorkWith',
#        'PlatformHaveWorkedWith', 'PlatformWantToWorkWith',
#        'WebframeHaveWorkedWith', 'WebframeWantToWorkWith',
#        'MiscTechHaveWorkedWith', 'MiscTechWantToWorkWith',
#        'ToolsTechHaveWorkedWith', 'ToolsTechWantToWorkWith',
#        'NEWCollabToolsHaveWorkedWith', 'NEWCollabToolsWantToWorkWith', 'OpSys',
#        'NEWStuck', 'NEWSOSites', 'SOVisitFreq', 'SOAccount', 'SOPartFreq',
#        'SOComm', 'NEWOtherComms', 'Age', 'Gender', 'Trans', 'Sexuality',
#        'Ethnicity', 'Accessibility', 'MentalHealth', 'SurveyLength',
#        'SurveyEase', 'ConvertedCompYearly'],
#       dtype='object')

# %% [markdown]
# ### Black coder count by state

# %%
black_st_value_counts=all_black_df['US_State'].value_counts(dropna=False).rename_axis('state').to_frame('counts').reset_index()
black_st_value_counts
# Out:
#                    state  counts
# 0             California      41
# 1               New York      38
# 2                  Texas      35
# 3                Florida      26
# 4               Maryland      26
# 5                Georgia      20
# 6               Virginia      20
# 7               Illinois      17
# 8               Michigan      14
# 9             Washington      14
# 10            New Jersey      14
# 11         Massachusetts      14
# 12                   NaN      13
# 13        North Carolina      12
# 14             Minnesota      12
# 15              Colorado       8
# 16                  Ohio       8
# 17          Pennsylvania       8
# 18  District of Columbia       7
# 19               Indiana       7
# 20        South Carolina       6
# 21               Arizona       5
# 22             Louisiana       5
# 23           Connecticut       5
# 24             Tennessee       4
# 25              Missouri       4
# 26                Oregon       4
# ...

# %%
import seaborn as sns
from matplotlib import pyplot as plt

plt.figure(figsize=(20,6))
sns.set(font_scale=1.25)
bar_black =sns.barplot(data=black_st_value_counts,x='state',y='counts')
bar_black.set_xticklabels(bar_black.get_xticklabels(),rotation = 80)
bar_black.set_title('Black Coders By State')
bar_black
# Out:
# <AxesSubplot:title={'center':'Black Coders By State'}, xlabel='state', ylabel='counts'>

# %% [markdown]
# Cali has most black survey respondents.  Largest state so makes sense based on size of black population.  Interesting that Maryland is in fourth place.  Maybe this is correlated with the amount of educated black people in Maryland.

# %% [markdown]
# ### Compare all coder by state to black coders by state

# %%
US_st_value_counts=USCoders['US_State'].value_counts(dropna=False).rename_axis('US State').to_frame('counts').reset_index()
US_st_value_counts.head(10)
# Out:
#         US State  counts
# 0     California    2163
# 1          Texas    1023
# 2       New York     961
# 3     Washington     932
# 4  Massachusetts     624
# 5        Florida     613
# 6       Illinois     587
# 7       Colorado     549
# 8   Pennsylvania     499
# 9       Virginia     453

# %%
plt.figure(figsize=(20,6))
sns.set(font_scale=1.25)
bar_US =sns.barplot(data=US_st_value_counts,x='US State',y='counts')
bar_US.set_xticklabels(bar_US.get_xticklabels(),rotation = 80)
bar_US.set_title('All Coders By State')
bar_US
# Out:
# <AxesSubplot:title={'center':'All Coders By State'}, xlabel='US State', ylabel='counts'>

# %% [markdown]
# ### Find most popular coding language for black coders

# %%
all_black_df['LanguageHaveWorkedWith'].value_counts(dropna=False)

# 7 null values for languageHaveWorkedWith
# Out:
# Python                                                                    12
# NaN                                                                        7
# HTML/CSS;JavaScript;Node.js;PHP                                            5
# Bash/Shell;HTML/CSS;JavaScript;Node.js;Python;SQL                          4
# HTML/CSS;JavaScript;Node.js;TypeScript                                     4
#                                                                           ..
# Bash/Shell;HTML/CSS;JavaScript;Node.js;Python;Ruby;SQL;TypeScript          1
# HTML/CSS;Java;JavaScript;Python;TypeScript                                 1
# JavaScript;Node.js                                                         1
# Groovy;HTML/CSS;JavaScript;Node.js;Python;TypeScript                       1
# C;C#;C++;HTML/CSS;Java;JavaScript;Matlab;Node.js;PHP;PowerShell;Python     1
# Name: LanguageHaveWorkedWith, Length: 366, dtype: int64

# %%
# all rows except for the NA's under LanguageHaveWorkedWith
language_df = all_black_df.loc[~all_black_df['LanguageHaveWorkedWith'].isnull()]

# %% [markdown]
# ##### Have to split up the languages worked with entry for each person surveyed in order to count the individual languages.  Use a counter to collect this info

# %%
from collections import Counter
language_counter = Counter()

# %%
#make dataframe for just LanguageHaveWorkedWith column
NEWlanguage_df = language_df['LanguageHaveWorkedWith']
NEWlanguage_df.head()
# Out:
# 1103    Bash/Shell;C;C++;Clojure;Go;HTML/CSS;Java;Java...
# 1399                    C++;JavaScript;Node.js;TypeScript
# 1662    Bash/Shell;HTML/CSS;JavaScript;Node.js;Python;...
# 2547                          C#;HTML/CSS;Java;Python;SQL
# 2998             Bash/Shell;C;PowerShell;Python;R;SQL;VBA
# Name: LanguageHaveWorkedWith, dtype: object

# %%
for response in NEWlanguage_df:
    language_counter.update(response.split(';'))

# %%
language_counter.most_common(20)
# Out:
# [('JavaScript', 290),
#  ('HTML/CSS', 255),
#  ('Python', 242),
#  ('Node.js', 184),
#  ('SQL', 177),
#  ('Java', 134),
#  ('Bash/Shell', 133),
#  ('TypeScript', 123),
#  ('C#', 99),
#  ('C++', 91),
#  ('C', 64),
#  ('PHP', 62),
#  ('PowerShell', 47),
#  ('Ruby', 46),
#  ('Go', 45),
#  ('Rust', 32),
#  ('Swift', 29),
#  ('Kotlin', 27),
#  ('Dart', 23),
#  ('R', 22)]

# %%
languages=[]
popularity=[]

for item in language_counter.most_common(20):
    languages.append(item[0])
    popularity.append(item[1])

# %%
#Find out how to make a dataframe out of the languages list and popularity list

dflanguage = {'language':languages,'Count':popularity}
dflanguage2=pd.DataFrame(dflanguage)
dflanguage2
# Out:
#       language  Count
# 0   JavaScript    290
# 1     HTML/CSS    255
# 2       Python    242
# 3      Node.js    184
# 4          SQL    177
# 5         Java    134
# 6   Bash/Shell    133
# 7   TypeScript    123
# 8           C#     99
# 9          C++     91
# 10           C     64
# 11         PHP     62
# 12  PowerShell     47
# 13        Ruby     46
# 14          Go     45
# 15        Rust     32
# 16       Swift     29
# 17      Kotlin     27
# 18        Dart     23
# 19           R     22

# %%
#plot the newly created language dataframe from above
plt.figure(figsize=(20,6))
language_bar =sns.barplot(data=dflanguage2,x='language',y='Count')
language_bar.set_xticklabels(language_bar.get_xticklabels(),rotation = 80)
language_bar.set_title('Black Coders Most Popular Language')
language_bar
# Out:
# <AxesSubplot:title={'center':'Black Coders Most Popular Language'}, xlabel='language', ylabel='Count'>

# %% [markdown]
# According to the survey, JavaSript is the most popular languge chosen by black coders with R being the least popular

# %% [markdown]
# ### Show most popular coding language with everybody else in US

# %%
all_black_df.head()
# Out:
#       ResponseId                                         MainBranch  \
# 1103        1104  I am not primarily a developer, but I write co...
# 1399        1400                        I code primarily as a hobby
# 1662        1663                     I am a developer by profession
# 2547        2548             I am a student who is learning to code
# 2998        2999  I am not primarily a developer, but I write co...
#
#               Employment                   Country  US_State UK_Country  \
# 1103  Employed full-time  United States of America   Florida        NaN
# 1399  Student, full-time  United States of America  Virginia        NaN
# 1662  Employed full-time  United States of America  Michigan        NaN
# 2547  Employed full-time  United States of America   Florida        NaN
# 2998  Employed full-time  United States of America  Illinois        NaN
#
#                                                 EdLevel     Age1stCode  \
# ...

# %% [markdown]
# ### Show discrepancy with pay between black men and black women

# %%
all_black_df['Gender'].value_counts()
# Out:
# Man                                                                                   363
# Woman                                                                                  44
# Woman;Non-binary, genderqueer, or gender non-conforming                                 5
# Or, in your own words:                                                                  5
# Non-binary, genderqueer, or gender non-conforming                                       4
# Prefer not to say                                                                       3
# Man;Or, in your own words:                                                              2
# Man;Woman;Non-binary, genderqueer, or gender non-conforming                             1
# Man;Non-binary, genderqueer, or gender non-conforming                                   1
# Non-binary, genderqueer, or gender non-conforming;Or, in your own words:                1
# ...

# %%
all_black_df.columns
# Out:
# Index(['ResponseId', 'MainBranch', 'Employment', 'Country', 'US_State',
#        'UK_Country', 'EdLevel', 'Age1stCode', 'LearnCode', 'YearsCode',
#        'YearsCodePro', 'DevType', 'OrgSize', 'Currency', 'CompTotal',
#        'CompFreq', 'LanguageHaveWorkedWith', 'LanguageWantToWorkWith',
#        'DatabaseHaveWorkedWith', 'DatabaseWantToWorkWith',
#        'PlatformHaveWorkedWith', 'PlatformWantToWorkWith',
#        'WebframeHaveWorkedWith', 'WebframeWantToWorkWith',
#        'MiscTechHaveWorkedWith', 'MiscTechWantToWorkWith',
#        'ToolsTechHaveWorkedWith', 'ToolsTechWantToWorkWith',
#        'NEWCollabToolsHaveWorkedWith', 'NEWCollabToolsWantToWorkWith', 'OpSys',
#        'NEWStuck', 'NEWSOSites', 'SOVisitFreq', 'SOAccount', 'SOPartFreq',
#        'SOComm', 'NEWOtherComms', 'Age', 'Gender', 'Trans', 'Sexuality',
#        'Ethnicity', 'Accessibility', 'MentalHealth', 'SurveyLength',
#        'SurveyEase', 'ConvertedCompYearly'],
#       dtype='object')

# %%
plt.figure(figsize=(45,30))
sns.set(font_scale=4)
gender_box =sns.boxplot(data=all_black_df,x='US_State',y='CompTotal')
gender_box.set_xticklabels(gender_box.get_xticklabels(),rotation = 90)
plt.ticklabel_format(style='plain',axis='y')  #changes y-axis labels from scientific notation to float
gender_box
# Out:
# <AxesSubplot:xlabel='US_State', ylabel='CompTotal'>

# %% [markdown]
# ## States broken down by education/employment (Black coders/All Coders)

# %%
def BlackHeat(feature):
    black_state_ed = all_black_df.pivot_table(index='US_State', columns=feature, values='ResponseId', aggfunc='count')
    plt.figure(figsize=(45,30))
    sns.set(font_scale=2.5)
    black_ed_heat = sns.heatmap(black_state_ed, cmap='Blues',linecolor='white',linewidth=2)
    black_ed_heat.set_title('Black Coders \n US State vs '+ feature)
    black_ed_heat

# %%
BlackHeat('EdLevel') #Heat map of states vs education level for black coders

# %% [markdown]
# Survey respondents with a bachelor's degree are the most popular across the states on average, with CA and NY having the most survey respondents within the bachelor's degree group.  The second most active columns looks to be survey respondents with some college.

# %%
BlackHeat('Employment') #Heat map of states vs employment for black coders

# %% [markdown]
# Texas and California leads survey respondents for full time employment.  Maryland showing a strong showing for full time employment for black survey respondents.  Maryland is close to the top for survey respondents that are full time students.

# %%
def heat(feature):
    US_state_ed = USCoders.pivot_table(index='US_State', columns=feature, values='ResponseId', aggfunc='count')
    plt.figure(figsize=(50,35))
    sns.set(font_scale=2.5)
    US_ed_heat = sns.heatmap(US_state_ed, cmap='Blues', linecolor='white',linewidth=2)
    US_ed_heat.set_title('US Coders \n US State vs '+ feature)
    US_ed_heat

# %%
heat('EdLevel') #Heat map of states vs education level for all coders

# %% [markdown]
# California has a strong lead for all survey respondents.  To be expected with the amount of tech jobs there and the population size of state.  Texas, NY, and Washington are next up.

# %%
heat('Employment') #Heat map of states vs employment for all coders
